# %%
from scipy.io import loadmat

vars = loadmat('sp_ln_sp_data.mat')
n = vars['n']
N = vars['N']
M = vars['M']
X = vars['X']
Y = vars['Y']

# %%
print(n.shape)
print(N.shape)
print(M.shape)
print(X.shape)
print(Y.shape)
# Out:
# (1, 1)
# (1, 1)
# (1, 1)
# (50, 50)
# (50, 50)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import itertools as it

# %%
oneDimX = list(it.chain(*X.tolist()))
oneDimY = list(it.chain(*Y.tolist()))

# %%
sns.regplot(oneDimX,oneDimY,line_kws={"color":"red"})
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d49c4e00-e54d-42d3-8cda-6e1a56ded0ed' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
